# %% [markdown]
# # ¿Qué es RDB y RDBMS?

# %% [markdown]
# * **RDB (Relational DataBase)**
# * **RDBMS (Relational DataBase Management System)** Sistema Manejador de Bases de datos relacionales.
#
# La diferencia entre ambos es que las BBDD son un conjunto de datos pertenecientes (o al menos en teoría) a un mismo tipo de contexto, que guarda los datos de forma persistente para un posterior uso, y el Sistema de gestión de BBDD o sistema manejador, es el que nos permite acceder a ella, es un software, herramienta que sirve de conexión entre las BBDD y el usuario (nos presenta una interfaz para poder gestionarla, manejarla).
#
# RDBMS
#
# - MySQL
# - PostgreSQL
# - SQL Server
# - Etc
#
# Todas toman un lenguaje base, pero cada uno lo apropia, imponiéndole diferentes reglas y características.

# %% [markdown]
# # Clientes gráficos

# %% [markdown]
# Dentro de las herramientas encontramos MySQL Workbench y mediante cliente gráfico que es una forma de entender una base de datos de manera mas simple.
#
# Para iniciar buscamos MySQL Workbench y nos aparecerá la siguiente pantalla en donde también nos muestra la conexión local por defecto:
#
# ![image.png](attachment:image.png)
#
# Damos click en la conexión local y nos mostrará una ventana emergente para ingresar la constraseña que asignamos en la instalación de MySQL.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Creación de una base de datos
#
# * Para crear una nueva base de datos damos click derecho sobre **Schemas** y posterior en **Create Schema**, una vez creada la base podemos darle un nombre y asignarle la secuencia de caracteres en este caso **UTF8**, para usar caracteres como la ñ.
#
# ![image.png](attachment:image.png)
#
# * Finalmente le damos click en **Apply** y nos da una ventana emergente con una traducción en lenguaje de BDD de la acción de creación anteriormente solicitada.
#
# ![image-2.png](attachment:image-2.png)
#
# * Una vez que comprobamos que todo es correcto damos click en **Apply** y nos dice que todos los cambios fueron exitosos.
#
# ![image-3.png](attachment:image-3.png)
#
# * Ahora ya nos aparece nuestra BDD **"curso_platzi"** y con ella podemos ejecutar varias acciones como crear nuevas tablas.
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Servicios Administrados o Cloud

# %% [markdown]
# Hoy en día muchas empresas ya no tienen instalados en sus servidores los RDBMS sino que los contratan a otras personas. Estos servicios administrados cloud te permiten concentrarte en la base de datos y no en su administración y actualización.
#
# Algunos Servicios Administrados tenemos:
#
# - Amazon Web Service (AWS)
# - Google Cloud Platform
# - Microsoft Azure
